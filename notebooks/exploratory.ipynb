# %%
import pandas as pd
import matplotlib.pyplot as plt
import cv2
import seaborn as sns

# %%
df = pd.read_csv("../data/train.csv")
df.head()
# Out:
#         id_code  diagnosis
# 0  000c1434d8d7          2
# 1  001639a390f0          4
# 2  0024cdab0c1e          1
# 3  002c21358ce6          0
# 4  005b95c28852          0

# %%
plt.figure(figsize=(6,4),dpi=200)
sns.countplot(data=df,x='diagnosis')
# Out:
# <Axes: xlabel='diagnosis', ylabel='count'>

# %%
df[df['diagnosis']!=0].value_counts().sum()
# Out:
# 1857
